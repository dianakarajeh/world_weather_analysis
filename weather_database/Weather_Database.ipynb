# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import pprint

from datetime import datetime
from config import weather_api_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/n8/6t7cp6ks5jjfscx03837nd040000gn/T/ipykernel_5738/1757139128.py in <module>
#       8
#       9 from datetime import datetime
# ---> 10 from config import weather_api_key
#
# ImportError: cannot import name 'weather_api_key' from 'config' (/Users/dianakarajeh/opt/anaconda3/lib/python3.9/site-packages/config/__init__.py)

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | namibe
# Processing Record 3 of Set 1 | sayyan
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | sussex
# Processing Record 6 of Set 1 | thai binh
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | maningrida
# Processing Record 11 of Set 1 | mareeba
# Processing Record 12 of Set 1 | kununurra
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | antofagasta
# Processing Record 15 of Set 1 | watsa
# Processing Record 16 of Set 1 | tongliao
# Processing Record 17 of Set 1 | pastavy
# Processing Record 18 of Set 1 | saldanha
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | brae
# Processing Record 21 of Set 1 | svetlogorsk
# Processing Record 22 of Set 1 | san cristobal
# Processing Record 23 of Set 1 | acarau
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | melito di porto salvo
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | leh
# Processing Record 32 of Set 1 | broome
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | rajshahi
# Processing Record 38 of Set 1 | shawinigan
# Processing Record 39 of Set 1 | dublin
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | dikson
# Processing Record 46 of Set 1 | inta
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | fort nelson
# Processing Record 49 of Set 1 | narsaq
# Processing Record 50 of Set 1 | kavieng
# Processing Record 1 of Set 2 | pundaguitan
# Processing Record 2 of Set 2 | vila
# Processing Record 3 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 2 | urucui
# Processing Record 5 of Set 2 | fortuna
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | ouegoa
# Processing Record 8 of Set 2 | chuy
# Processing Record 9 of Set 2 | zharkovskiy
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | beringovskiy
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | yulara
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | provideniya
# Processing Record 17 of Set 2 | ilulissat
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | eirunepe
# Processing Record 20 of Set 2 | palmer
# Processing Record 21 of Set 2 | iberia
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | nanortalik
# Processing Record 24 of Set 2 | balclutha
# Processing Record 25 of Set 2 | kisangani
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | magdagachi
# Processing Record 30 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 2 | olinda
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | belyy yar
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | halifax
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | arman
# Processing Record 38 of Set 2 | srednekolymsk
# Processing Record 39 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 2 | moba
# Processing Record 41 of Set 2 | roswell
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | gornopravdinsk
# Processing Record 44 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 2 | zaranj
# Processing Record 46 of Set 2 | aykhal
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | khash
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | grindavik
# Processing Record 6 of Set 3 | namatanai
# Processing Record 7 of Set 3 | kargasok
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | krasnokamensk
# Processing Record 10 of Set 3 | moron
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | oriximina
# Processing Record 14 of Set 3 | dangriga
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | inuvik
# Processing Record 17 of Set 3 | hope
# Processing Record 18 of Set 3 | cockburn town
# Processing Record 19 of Set 3 | begowal
# Processing Record 20 of Set 3 | matara
# Processing Record 21 of Set 3 | barinas
# Processing Record 22 of Set 3 | aitape
# Processing Record 23 of Set 3 | westport
# Processing Record 24 of Set 3 | beloha
# Processing Record 25 of Set 3 | challapata
# Processing Record 26 of Set 3 | cap malheureux
# Processing Record 27 of Set 3 | sur
# Processing Record 28 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 3 | hasaki
# Processing Record 30 of Set 3 | wenatchee
# Processing Record 31 of Set 3 | sangar
# Processing Record 32 of Set 3 | yanam
# Processing Record 33 of Set 3 | sistranda
# Processing Record 34 of Set 3 | praia da vitoria
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | hamilton
# Processing Record 37 of Set 3 | tazovskiy
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | ixtapa
# Processing Record 41 of Set 3 | hede
# Processing Record 42 of Set 3 | lagoa
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | ponta do sol
# Processing Record 45 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 3 | kapaa
# Processing Record 47 of Set 3 | axim
# Processing Record 48 of Set 3 | guerrero negro
# Processing Record 49 of Set 3 | fort-shevchenko
# Processing Record 50 of Set 3 | lamar
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 4 | trairi
# Processing Record 5 of Set 4 | safaqis
# City not found. Skipping...
# Processing Record 6 of Set 4 | nuevitas
# Processing Record 7 of Set 4 | wanning
# Processing Record 8 of Set 4 | villa maria
# Processing Record 9 of Set 4 | vila velha
# Processing Record 10 of Set 4 | avera
# Processing Record 11 of Set 4 | makakilo city
# Processing Record 12 of Set 4 | katsuura
# Processing Record 13 of Set 4 | wasilla
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | bilma
# Processing Record 17 of Set 4 | kodinsk
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | oistins
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | lahaina
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | port alfred
# Processing Record 24 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | lotofaga
# Processing Record 27 of Set 4 | gaurela
# Processing Record 28 of Set 4 | cuamba
# Processing Record 29 of Set 4 | flinders
# Processing Record 30 of Set 4 | poronaysk
# Processing Record 31 of Set 4 | maldonado
# Processing Record 32 of Set 4 | barrow
# Processing Record 33 of Set 4 | malakal
# Processing Record 34 of Set 4 | vilyuysk
# Processing Record 35 of Set 4 | shyryayeve
# Processing Record 36 of Set 4 | takaka
# Processing Record 37 of Set 4 | whitianga
# Processing Record 38 of Set 4 | asau
# Processing Record 39 of Set 4 | broken hill
# Processing Record 40 of Set 4 | abong mbang
# Processing Record 41 of Set 4 | cedar city
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | bourail
# Processing Record 44 of Set 4 | shumskiy
# Processing Record 45 of Set 4 | airai
# Processing Record 46 of Set 4 | anchorage
# Processing Record 47 of Set 4 | rairangpur
# Processing Record 48 of Set 4 | boca do acre
# Processing Record 49 of Set 4 | diego de almagro
# Processing Record 50 of Set 4 | tanout
# Processing Record 1 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 5 | bara
# Processing Record 3 of Set 5 | lavrentiya
# Processing Record 4 of Set 5 | huntsville
# Processing Record 5 of Set 5 | batticaloa
# Processing Record 6 of Set 5 | moctezuma
# Processing Record 7 of Set 5 | camacupa
# Processing Record 8 of Set 5 | pangnirtung
# Processing Record 9 of Set 5 | burnie
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 5 | alice springs
# Processing Record 14 of Set 5 | cayenne
# Processing Record 15 of Set 5 | pinos
# Processing Record 16 of Set 5 | nantucket
# Processing Record 17 of Set 5 | batagay-alyta
# Processing Record 18 of Set 5 | walvis bay
# Processing Record 19 of Set 5 | xuddur
# Processing Record 20 of Set 5 | kidal
# Processing Record 21 of Set 5 | severnyy
# Processing Record 22 of Set 5 | caxito
# Processing Record 23 of Set 5 | pisco
# Processing Record 24 of Set 5 | ca mau
# Processing Record 25 of Set 5 | thompson
# Processing Record 26 of Set 5 | prince rupert
# Processing Record 27 of Set 5 | bonthe
# Processing Record 28 of Set 5 | santa helena de goias
# Processing Record 29 of Set 5 | weyburn
# Processing Record 30 of Set 5 | gold coast
# Processing Record 31 of Set 5 | wattegama
# Processing Record 32 of Set 5 | luanda
# Processing Record 33 of Set 5 | iracoubo
# Processing Record 34 of Set 5 | san vicente
# Processing Record 35 of Set 5 | kungurtug
# Processing Record 36 of Set 5 | oytal
# Processing Record 37 of Set 5 | alekseyevskoye
# Processing Record 38 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 5 | meulaboh
# Processing Record 40 of Set 5 | bengkulu
# Processing Record 41 of Set 5 | mao
# Processing Record 42 of Set 5 | pran buri
# Processing Record 43 of Set 5 | makurdi
# Processing Record 44 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 5 | conceicao da feira
# Processing Record 46 of Set 5 | nueva gorgona
# Processing Record 47 of Set 5 | kloulklubed
# Processing Record 48 of Set 5 | foam lake
# Processing Record 49 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 5 | saurimo
# Processing Record 1 of Set 6 | troitsko-pechorsk
# Processing Record 2 of Set 6 | ubatuba
# Processing Record 3 of Set 6 | vytegra
# Processing Record 4 of Set 6 | minas de barroteran
# Processing Record 5 of Set 6 | patiya
# Processing Record 6 of Set 6 | port blair
# Processing Record 7 of Set 6 | iqaluit
# Processing Record 8 of Set 6 | bam
# Processing Record 9 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 10 of Set 6 | coahuayana
# Processing Record 11 of Set 6 | aguimes
# Processing Record 12 of Set 6 | karasburg
# Processing Record 13 of Set 6 | klaksvik
# Processing Record 14 of Set 6 | mayo
# Processing Record 15 of Set 6 | shadegan
# Processing Record 16 of Set 6 | port dickson
# Processing Record 17 of Set 6 | kendallville
# Processing Record 18 of Set 6 | dingle
# Processing Record 19 of Set 6 | marzuq
# Processing Record 20 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 6 | saint-pierre
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | tetouan
# Processing Record 24 of Set 6 | nola
# Processing Record 25 of Set 6 | saskylakh
# Processing Record 26 of Set 6 | shihezi
# Processing Record 27 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 6 | kota kinabalu
# Processing Record 30 of Set 6 | mount gambier
# Processing Record 31 of Set 6 | luwuk
# Processing Record 32 of Set 6 | mehamn
# Processing Record 33 of Set 6 | rapid city
# Processing Record 34 of Set 6 | yumen
# Processing Record 35 of Set 6 | mazagao
# Processing Record 36 of Set 6 | chapais
# Processing Record 37 of Set 6 | ushirombo
# Processing Record 38 of Set 6 | hammerfest
# Processing Record 39 of Set 6 | gambo
# Processing Record 40 of Set 6 | manta
# Processing Record 41 of Set 6 | kaseda
# Processing Record 42 of Set 6 | huejuquilla el alto
# Processing Record 43 of Set 6 | ellisras
# Processing Record 44 of Set 6 | kailua
# Processing Record 45 of Set 6 | teguldet
# Processing Record 46 of Set 6 | hvide sande
# Processing Record 47 of Set 6 | hadgaon
# Processing Record 48 of Set 6 | college
# Processing Record 49 of Set 6 | xiashi
# Processing Record 50 of Set 6 | uvinza
# Processing Record 1 of Set 7 | alugan
# Processing Record 2 of Set 7 | rio grande
# Processing Record 3 of Set 7 | alofi
# Processing Record 4 of Set 7 | victoria
# Processing Record 5 of Set 7 | zhanaozen
# Processing Record 6 of Set 7 | ostrovnoy
# Processing Record 7 of Set 7 | richards bay
# Processing Record 8 of Set 7 | salym
# Processing Record 9 of Set 7 | arroyos y esteros
# Processing Record 10 of Set 7 | mbandaka
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | yeppoon
# Processing Record 13 of Set 7 | riberalta
# Processing Record 14 of Set 7 | isangel
# Processing Record 15 of Set 7 | evensk
# Processing Record 16 of Set 7 | colac
# Processing Record 17 of Set 7 | ola
# Processing Record 18 of Set 7 | kama
# Processing Record 19 of Set 7 | sitka
# Processing Record 20 of Set 7 | hue
# Processing Record 21 of Set 7 | cooma
# Processing Record 22 of Set 7 | lyuban
# Processing Record 23 of Set 7 | usinsk
# Processing Record 24 of Set 7 | sompeta
# Processing Record 25 of Set 7 | ajdabiya
# Processing Record 26 of Set 7 | bluefields
# Processing Record 27 of Set 7 | portland
# Processing Record 28 of Set 7 | canoinhas
# Processing Record 29 of Set 7 | beisfjord
# Processing Record 30 of Set 7 | bani
# Processing Record 31 of Set 7 | sheltozero
# Processing Record 32 of Set 7 | ankang
# Processing Record 33 of Set 7 | nayoro
# Processing Record 34 of Set 7 | phan thiet
# Processing Record 35 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 7 | wollongong
# Processing Record 37 of Set 7 | kemi
# Processing Record 38 of Set 7 | corrientes
# Processing Record 39 of Set 7 | dourbali
# Processing Record 40 of Set 7 | arlit
# Processing Record 41 of Set 7 | vila franca do campo
# Processing Record 42 of Set 7 | villa carlos paz
# Processing Record 43 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 44 of Set 7 | mayumba
# Processing Record 45 of Set 7 | alta floresta
# Processing Record 46 of Set 7 | oranjemund
# Processing Record 47 of Set 7 | ormara
# Processing Record 48 of Set 7 | kochevo
# Processing Record 49 of Set 7 | muhos
# Processing Record 50 of Set 7 | cherskiy
# Processing Record 1 of Set 8 | sabha
# Processing Record 2 of Set 8 | norsup
# Processing Record 3 of Set 8 | bathsheba
# Processing Record 4 of Set 8 | thinadhoo
# Processing Record 5 of Set 8 | ahipara
# Processing Record 6 of Set 8 | san carlos de bariloche
# Processing Record 7 of Set 8 | baiyin
# Processing Record 8 of Set 8 | manzini
# Processing Record 9 of Set 8 | egvekinot
# Processing Record 10 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 8 | hay river
# Processing Record 12 of Set 8 | ruy barbosa
# Processing Record 13 of Set 8 | saint-augustin
# Processing Record 14 of Set 8 | vologda
# Processing Record 15 of Set 8 | farah
# Processing Record 16 of Set 8 | bonavista
# Processing Record 17 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 8 | tyler
# Processing Record 19 of Set 8 | dzaoudzi
# Processing Record 20 of Set 8 | tuatapere
# Processing Record 21 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 8 | whitehorse
# Processing Record 23 of Set 8 | lorengau
# Processing Record 24 of Set 8 | cabo san lucas
# Processing Record 25 of Set 8 | port lincoln
# Processing Record 26 of Set 8 | fare
# Processing Record 27 of Set 8 | botro
# Processing Record 28 of Set 8 | yuksekova
# Processing Record 29 of Set 8 | port hawkesbury
# Processing Record 30 of Set 8 | srivardhan
# Processing Record 31 of Set 8 | north platte
# Processing Record 32 of Set 8 | bingol
# Processing Record 33 of Set 8 | kajaani
# Processing Record 34 of Set 8 | norman wells
# Processing Record 35 of Set 8 | lata
# Processing Record 36 of Set 8 | san patricio
# Processing Record 37 of Set 8 | ancud
# Processing Record 38 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 8 | key west
# Processing Record 40 of Set 8 | dakar
# Processing Record 41 of Set 8 | nurota
# Processing Record 42 of Set 8 | abha
# Processing Record 43 of Set 8 | takoradi
# Processing Record 44 of Set 8 | tautira
# Processing Record 45 of Set 8 | cerrito
# Processing Record 46 of Set 8 | kodiak
# Processing Record 47 of Set 8 | bubaque
# Processing Record 48 of Set 8 | somerton
# Processing Record 49 of Set 8 | terrace
# Processing Record 50 of Set 8 | bargarh
# Processing Record 1 of Set 9 | valparaiso
# Processing Record 2 of Set 9 | sambava
# Processing Record 3 of Set 9 | jumla
# Processing Record 4 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 9 | olafsvik
# Processing Record 6 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 7 of Set 9 | rocha
# Processing Record 8 of Set 9 | eydhafushi
# Processing Record 9 of Set 9 | moerai
# Processing Record 10 of Set 9 | martapura
# Processing Record 11 of Set 9 | saint-prosper
# Processing Record 12 of Set 9 | cangzhou
# Processing Record 13 of Set 9 | paita
# Processing Record 14 of Set 9 | kirakira
# Processing Record 15 of Set 9 | aanekoski
# Processing Record 16 of Set 9 | galesong
# Processing Record 17 of Set 9 | winneba
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | mogadishu
# Processing Record 20 of Set 9 | faanui
# Processing Record 21 of Set 9 | zhengjiatun
# Processing Record 22 of Set 9 | bijie
# Processing Record 23 of Set 9 | zilair
# Processing Record 24 of Set 9 | zverinogolovskoye
# Processing Record 25 of Set 9 | krasnoselkup
# Processing Record 26 of Set 9 | misratah
# Processing Record 27 of Set 9 | noumea
# Processing Record 28 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 9 | vestmannaeyjar
# Processing Record 30 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 9 | mokhotlong
# Processing Record 32 of Set 9 | itahari
# City not found. Skipping...
# Processing Record 33 of Set 9 | monrovia
# Processing Record 34 of Set 9 | urdoma
# Processing Record 35 of Set 9 | luancheng
# Processing Record 36 of Set 9 | puerto del rosario
# Processing Record 37 of Set 9 | japura
# Processing Record 38 of Set 9 | belmonte
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | sao joao da barra
# Processing Record 41 of Set 9 | balancan
# Processing Record 42 of Set 9 | tura
# Processing Record 43 of Set 9 | maham
# Processing Record 44 of Set 9 | leningradskiy
# Processing Record 45 of Set 9 | qasigiannguit
# Processing Record 46 of Set 9 | san pedro
# Processing Record 47 of Set 9 | urumqi
# Processing Record 48 of Set 9 | hofn
# Processing Record 49 of Set 9 | shima
# Processing Record 50 of Set 9 | san policarpo
# Processing Record 1 of Set 10 | komsomolskiy
# Processing Record 2 of Set 10 | kavaratti
# Processing Record 3 of Set 10 | atambua
# Processing Record 4 of Set 10 | tarko-sale
# Processing Record 5 of Set 10 | jacareacanga
# Processing Record 6 of Set 10 | amapa
# Processing Record 7 of Set 10 | kiruna
# Processing Record 8 of Set 10 | canyon
# Processing Record 9 of Set 10 | constitucion
# Processing Record 10 of Set 10 | eureka
# Processing Record 11 of Set 10 | kamenka
# Processing Record 12 of Set 10 | ambon
# Processing Record 13 of Set 10 | la plaine
# Processing Record 14 of Set 10 | mixtequilla
# City not found. Skipping...
# Processing Record 15 of Set 10 | vestmanna
# Processing Record 16 of Set 10 | mehriz
# Processing Record 17 of Set 10 | esperance
# Processing Record 18 of Set 10 | weiden
# Processing Record 19 of Set 10 | redlands
# Processing Record 20 of Set 10 | sayat
# Processing Record 21 of Set 10 | marquette
# Processing Record 22 of Set 10 | oksfjord
# Processing Record 23 of Set 10 | atar
# Processing Record 24 of Set 10 | warmbad
# Processing Record 25 of Set 10 | port hardy
# Processing Record 26 of Set 10 | arcachon
# Processing Record 27 of Set 10 | el prat de llobregat
# Processing Record 28 of Set 10 | benghazi
# Processing Record 29 of Set 10 | slobodskoy
# Processing Record 30 of Set 10 | pacific grove
# Processing Record 31 of Set 10 | matay
# Processing Record 32 of Set 10 | nove hrady
# Processing Record 33 of Set 10 | burica
# City not found. Skipping...
# Processing Record 34 of Set 10 | maniitsoq
# Processing Record 35 of Set 10 | claudio
# Processing Record 36 of Set 10 | khorinsk
# Processing Record 37 of Set 10 | yining
# Processing Record 38 of Set 10 | ternate
# Processing Record 39 of Set 10 | palu
# Processing Record 40 of Set 10 | dunn
# Processing Record 41 of Set 10 | timbiqui
# Processing Record 42 of Set 10 | ust-kulom
# Processing Record 43 of Set 10 | turukhansk
# Processing Record 44 of Set 10 | labuhan
# Processing Record 45 of Set 10 | gobabis
# Processing Record 46 of Set 10 | svarychiv
# Processing Record 47 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 49 of Set 10 | ballina
# Processing Record 50 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 11 | saint anthony
# Processing Record 2 of Set 11 | blagoyevo
# Processing Record 3 of Set 11 | kandrian
# Processing Record 4 of Set 11 | natal
# Processing Record 5 of Set 11 | lompoc
# Processing Record 6 of Set 11 | dunedin
# Processing Record 7 of Set 11 | cairns
# Processing Record 8 of Set 11 | bad kissingen
# Processing Record 9 of Set 11 | thiruvananthapuram
# Processing Record 10 of Set 11 | nechi
# Processing Record 11 of Set 11 | hovd
# Processing Record 12 of Set 11 | salinopolis
# Processing Record 13 of Set 11 | sal rei
# Processing Record 14 of Set 11 | buarcos
# Processing Record 15 of Set 11 | longyearbyen
# Processing Record 16 of Set 11 | deputatskiy
# Processing Record 17 of Set 11 | victor harbor
# Processing Record 18 of Set 11 | havelock
# Processing Record 19 of Set 11 | manama
# Processing Record 20 of Set 11 | cananeia
# Processing Record 21 of Set 11 | high rock
# Processing Record 22 of Set 11 | kijang
# Processing Record 23 of Set 11 | arkhangelsk
# Processing Record 24 of Set 11 | menongue
# Processing Record 25 of Set 11 | grand gaube
# Processing Record 26 of Set 11 | puerto escondido
# Processing Record 27 of Set 11 | luena
# Processing Record 28 of Set 11 | miri
# Processing Record 29 of Set 11 | naranjal
# Processing Record 30 of Set 11 | lakes entrance
# Processing Record 31 of Set 11 | boguchany
# Processing Record 32 of Set 11 | loralai
# Processing Record 33 of Set 11 | paragominas
# Processing Record 34 of Set 11 | asfi
# Processing Record 35 of Set 11 | kuching
# Processing Record 36 of Set 11 | nordhausen
# Processing Record 37 of Set 11 | zhigansk
# Processing Record 38 of Set 11 | farkhor
# Processing Record 39 of Set 11 | peace river
# Processing Record 40 of Set 11 | tecoanapa
# Processing Record 41 of Set 11 | quang ngai
# Processing Record 42 of Set 11 | half moon bay
# Processing Record 43 of Set 11 | palembang
# Processing Record 44 of Set 11 | ituiutaba
# Processing Record 45 of Set 11 | agogo
# Processing Record 46 of Set 11 | banda aceh
# Processing Record 47 of Set 11 | grand-santi
# Processing Record 48 of Set 11 | kruisfontein
# Processing Record 49 of Set 11 | huadian
# Processing Record 50 of Set 11 | ridgecrest
# Processing Record 1 of Set 12 | arambagh
# Processing Record 2 of Set 12 | pontianak
# Processing Record 3 of Set 12 | sampit
# Processing Record 4 of Set 12 | mopti
# Processing Record 5 of Set 12 | la rioja
# Processing Record 6 of Set 12 | buala
# Processing Record 7 of Set 12 | bati
# Processing Record 8 of Set 12 | gamba
# Processing Record 9 of Set 12 | careiro da varzea
# Processing Record 10 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 11 of Set 12 | rabo de peixe
# Processing Record 12 of Set 12 | gravdal
# Processing Record 13 of Set 12 | riviere-au-renard
# Processing Record 14 of Set 12 | homer
# Processing Record 15 of Set 12 | vaitape
# Processing Record 16 of Set 12 | viedma
# Processing Record 17 of Set 12 | bamberg
# Processing Record 18 of Set 12 | kedzierzyn-kozle
# Processing Record 19 of Set 12 | waitati
# Processing Record 20 of Set 12 | hambantota
# Processing Record 21 of Set 12 | laguna
# Processing Record 22 of Set 12 | port shepstone
# Processing Record 23 of Set 12 | coihaique
# Processing Record 24 of Set 12 | shahreza
# Processing Record 25 of Set 12 | thionville
# Processing Record 26 of Set 12 | salalah
# Processing Record 27 of Set 12 | de-kastri
# Processing Record 28 of Set 12 | havoysund
# Processing Record 29 of Set 12 | mackay
# Processing Record 30 of Set 12 | dhekiajuli
# Processing Record 31 of Set 12 | methoni
# Processing Record 32 of Set 12 | sao bento do sul
# Processing Record 33 of Set 12 | balgazyn
# Processing Record 34 of Set 12 | ler
# Processing Record 35 of Set 12 | ewo
# Processing Record 36 of Set 12 | pervoavgustovskiy
# Processing Record 37 of Set 12 | utica
# Processing Record 38 of Set 12 | mokhsogollokh
# Processing Record 39 of Set 12 | esmeraldas
# Processing Record 40 of Set 12 | ibra
# Processing Record 41 of Set 12 | santa maria
# Processing Record 42 of Set 12 | vizinga
# Processing Record 43 of Set 12 | barra do corda
# Processing Record 44 of Set 12 | mansehra
# Processing Record 45 of Set 12 | belize
# Processing Record 46 of Set 12 | keuruu
# Processing Record 47 of Set 12 | mocajuba
# Processing Record 48 of Set 12 | pitkyaranta
# Processing Record 49 of Set 12 | lundazi
# Processing Record 50 of Set 12 | manggar
# Processing Record 1 of Set 13 | coffs harbour
# Processing Record 2 of Set 13 | sturgeon bay
# Processing Record 3 of Set 13 | sorong
# Processing Record 4 of Set 13 | otukpo
# Processing Record 5 of Set 13 | mana
# Processing Record 6 of Set 13 | maceio
# Processing Record 7 of Set 13 | ust-nera
# Processing Record 8 of Set 13 | kamaishi
# Processing Record 9 of Set 13 | hobyo
# Processing Record 10 of Set 13 | santa marinella
# Processing Record 11 of Set 13 | anadyr
# Processing Record 12 of Set 13 | padang
# Processing Record 13 of Set 13 | vizimyary
# City not found. Skipping...
# Processing Record 14 of Set 13 | pilar
# Processing Record 15 of Set 13 | nuuk
# Processing Record 16 of Set 13 | kalangala
# Processing Record 17 of Set 13 | vidim
# Processing Record 18 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 13 | yar-sale
# Processing Record 20 of Set 13 | abu kamal
# Processing Record 21 of Set 13 | kemijarvi
# Processing Record 22 of Set 13 | awjilah
# Processing Record 23 of Set 13 | tezu
# Processing Record 24 of Set 13 | san quintin
# Processing Record 25 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 13 | bairiki
# Processing Record 27 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 13 | inhambane
# Processing Record 29 of Set 13 | verkhoyansk
# Processing Record 30 of Set 13 | tessalit
# Processing Record 31 of Set 13 | kendari
# Processing Record 32 of Set 13 | trapani
# Processing Record 33 of Set 13 | aykino
# Processing Record 34 of Set 13 | aksarka
# Processing Record 35 of Set 13 | filadelfia
# Processing Record 36 of Set 13 | filingue
# Processing Record 37 of Set 13 | payakumbuh
# Processing Record 38 of Set 13 | olavarria
# Processing Record 39 of Set 13 | hualmay
# Processing Record 40 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 13 | tavistock
# Processing Record 42 of Set 13 | baytown
# Processing Record 43 of Set 13 | souillac
# Processing Record 44 of Set 13 | nishihara
# Processing Record 45 of Set 13 | pedernales
# Processing Record 46 of Set 13 | kholtoson
# Processing Record 47 of Set 13 | bitlis
# Processing Record 48 of Set 13 | maxixe
# Processing Record 49 of Set 13 | miles city
# Processing Record 50 of Set 13 | biltine
# Processing Record 1 of Set 14 | saravan
# Processing Record 2 of Set 14 | chabahar
# Processing Record 3 of Set 14 | morondava
# Processing Record 4 of Set 14 | pahrump
# Processing Record 5 of Set 14 | sinnamary
# Processing Record 6 of Set 14 | polunochnoye
# Processing Record 7 of Set 14 | akonolinga
# Processing Record 8 of Set 14 | saint helens
# Processing Record 9 of Set 14 | moree
# Processing Record 10 of Set 14 | krasnoborsk
# Processing Record 11 of Set 14 | marathon
# Processing Record 12 of Set 14 | tambul
# City not found. Skipping...
# Processing Record 13 of Set 14 | pendleton
# Processing Record 14 of Set 14 | noyabrsk
# Processing Record 15 of Set 14 | jerome
# Processing Record 16 of Set 14 | monte azul
# Processing Record 17 of Set 14 | denpasar
# Processing Record 18 of Set 14 | reyes
# Processing Record 19 of Set 14 | teruel
# Processing Record 20 of Set 14 | comodoro rivadavia
# Processing Record 21 of Set 14 | guerrero
# Processing Record 22 of Set 14 | ranau
# Processing Record 23 of Set 14 | angoche
# Processing Record 24 of Set 14 | lumajang
# Processing Record 25 of Set 14 | aklavik
# Processing Record 26 of Set 14 | mapastepec
# Processing Record 27 of Set 14 | kaeo
# Processing Record 28 of Set 14 | lalin
# Processing Record 29 of Set 14 | aleksandrov gay
# Processing Record 30 of Set 14 | conde
# Processing Record 31 of Set 14 | kropotkin
# Processing Record 32 of Set 14 | lynn haven
# Processing Record 33 of Set 14 | catuday
# Processing Record 34 of Set 14 | goundam
# Processing Record 35 of Set 14 | vostok
# Processing Record 36 of Set 14 | hit
# Processing Record 37 of Set 14 | myitkyina
# Processing Record 38 of Set 14 | vanimo
# Processing Record 39 of Set 14 | plettenberg bay
# Processing Record 40 of Set 14 | tunxi
# City not found. Skipping...
# Processing Record 41 of Set 14 | nhulunbuy
# Processing Record 42 of Set 14 | macusani
# Processing Record 43 of Set 14 | sobolevo
# Processing Record 44 of Set 14 | piacabucu
# Processing Record 45 of Set 14 | talcahuano
# Processing Record 46 of Set 14 | sao gabriel da cachoeira
# Processing Record 47 of Set 14 | santa cruz
# Processing Record 48 of Set 14 | lasa
# Processing Record 49 of Set 14 | ponta delgada
# Processing Record 50 of Set 14 | huarmey
# Processing Record 1 of Set 15 | kieta
# Processing Record 2 of Set 15 | svetlyy
# Processing Record 3 of Set 15 | lampa
# Processing Record 4 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 15 | mossendjo
# Processing Record 6 of Set 15 | cabinda
# Processing Record 7 of Set 15 | chanika
# Processing Record 8 of Set 15 | brindisi
# Processing Record 9 of Set 15 | sines
# Processing Record 10 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 15 | sun city west
# Processing Record 12 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set 15 | northam
# Processing Record 14 of Set 15 | ubinskoye
# Processing Record 15 of Set 15 | ekhabi
# Processing Record 16 of Set 15 | benguela
# Processing Record 17 of Set 15 | bodden town
# Processing Record 18 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 15 | wajima
# Processing Record 20 of Set 15 | pailon
# Processing Record 21 of Set 15 | labytnangi
# Processing Record 22 of Set 15 | hawkesbury
# Processing Record 23 of Set 15 | west richland
# Processing Record 24 of Set 15 | skibbereen
# Processing Record 25 of Set 15 | hirara
# Processing Record 26 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 15 | madisonville
# Processing Record 28 of Set 15 | saint george
# Processing Record 29 of Set 15 | razole
# Processing Record 30 of Set 15 | amahai
# Processing Record 31 of Set 15 | shenjiamen
# Processing Record 32 of Set 15 | oshnaviyeh
# Processing Record 33 of Set 15 | lebyazhye
# Processing Record 34 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 15 | klenovyy
# Processing Record 36 of Set 15 | san luis
# Processing Record 37 of Set 15 | skagen
# Processing Record 38 of Set 15 | kapuskasing
# Processing Record 39 of Set 15 | beihai
# Processing Record 40 of Set 15 | karratha
# Processing Record 41 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 42 of Set 15 | mabaruma
# Processing Record 43 of Set 15 | touros
# Processing Record 44 of Set 15 | ketchikan
# Processing Record 45 of Set 15 | vrangel
# Processing Record 46 of Set 15 | charyshskoye
# Processing Record 47 of Set 15 | tabou
# Processing Record 48 of Set 15 | manga
# Processing Record 49 of Set 15 | manokwari
# Processing Record 50 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 16 | araripina
# Processing Record 2 of Set 16 | adrar
# Processing Record 3 of Set 16 | hindaun
# Processing Record 4 of Set 16 | antoniny
# Processing Record 5 of Set 16 | smidovich
# Processing Record 6 of Set 16 | abu samrah
# Processing Record 7 of Set 16 | corn island
# Processing Record 8 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 16 | novyy urengoy
# Processing Record 10 of Set 16 | gayeri
# Processing Record 11 of Set 16 | beyla
# Processing Record 12 of Set 16 | ambulu
# Processing Record 13 of Set 16 | wanxian
# Processing Record 14 of Set 16 | mattru
# Processing Record 15 of Set 16 | kasongo-lunda
# Processing Record 16 of Set 16 | taksimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 709

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mataura      NZ -46.1927  168.8643     44.49        97          99
# 1       Namibe      AO -15.1961   12.1522     70.86        81         100
# 2       Sayyan      YE  15.1718   44.3244     59.77        20          91
# 3        Tiksi      RU  71.6872  128.8694      5.36        98         100
# 4       Sussex      US  41.1834  -74.6663     44.69        79         100
# 5    Thai Binh      VN  20.4500  106.3333     63.52        64          84
# 6   Chokurdakh      RU  70.6333  147.9167    -21.60       100          84
# 7   Bredasdorp      ZA -34.5322   20.0403     62.76        84          79
# 8  East London      ZA -33.0153   27.9116     73.02        89         100
# 9   Maningrida      AU -12.0667  134.2667     77.13        84          84
#
#    Wind Speed Current Description
# 0        2.19     overcast clouds
# 1        9.75     overcast clouds
# 2        5.30     overcast clouds
# 3        8.05     overcast clouds
# 4        4.61     overcast clouds
# 5        3.71       broken clouds
# 6        3.04       broken clouds
# 7        3.80       broken clouds
# 8       18.14     overcast clouds
# 9        3.04       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
